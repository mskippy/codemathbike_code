# %% [markdown]
# # Project 1Z — Open Stretch
#
# Fully self-directed. Show your teacher something you haven't been taught in this course yet — a language feature, a library, a technique you found on your own. It doesn't need to be complicated; it needs to be genuinely yours, and genuinely documented.

# %% [markdown]
# ## Requirements
#
# 1. **Something not directly taught in Unit 1** — a new built-in function, a module you found and learned to use, a technique from outside class
# 2. **It has to actually work** — run it, test it, confirm it does what you say it does
# 3. **Documented well** — explain what it is, where you learned about it, and why you chose it, in the markdown cell below
# 4. Connects to the adventure-game world if it naturally fits — but it doesn't have to; the point of this one is showing initiative, not staying on-theme

# %% [markdown]
# **What I explored, and why:** *(double-click to edit this cell — describe what you found, where you learned it, and why you picked it)*

# %%
# Build your exploration here.

# %% [markdown]
# ## Before You Commit
#
# Make sure someone else (your teacher, a classmate) could run this cell and understand what it's doing from your documentation alone — that's the actual bar for "well documented," not just "I understand it.

# %% [markdown]
# ## AI Collaboration Log
#
# If you used AI for any part of this project, log it here before you commit — same habit as your portfolio README:
#
# - What did you ask for?
# - What did you keep, and what did you change?
#
# *(If you didn't use AI this time, just write "Didn't use AI for this one.")*
#
# **Your log:** *(double-click to edit this cell)*
