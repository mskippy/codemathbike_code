# %% [markdown]
# # Project 1C — Inventory & the Full Game
#
# **Checkpoint 3 of 3 — the finish line.** Open your Project 1B notebook and keep building from there. Today you add an inventory (a list) to your adventure, and then debug a version of your own game with a few deliberately planted bugs before final submission. By the end, you'll have one complete, playable game in your portfolio.

# %% [markdown]
# ## Requirements
#
# **Tier 1 — Minimum viable:**
# 1. Copy your Project 1B code in as a starting point
# 2. An inventory **list** that starts with at least one item
# 3. At least one place in your adventure where an item gets **added** to the inventory (`.append()`), and one place where the inventory is **printed** for the player to see
# 4. Once your game runs cleanly end-to-end, deliberately introduce **2–3 bugs** into a *copy* of your working code in the cell below (keep your working version safe above it) — a typo, an off-by-one, a wrong comparison, whatever you like — then fix them one at a time, the way you practiced in 1.8
#
# **Tier 2 — Aim for this:**
# - The inventory affects the story somehow — e.g. a room checks whether a specific item is in the list before allowing a choice
# - Your planted bugs cover at least two different error categories from 1.8 (e.g. one crash-type error, one silent logic bug)
#
# **Tier 3 — Stretch:**
# - Let the player remove an item from the inventory too (used or lost), not just add
# - Write a one-paragraph "postmortem" in a markdown cell: what was the trickiest bug to find, and how did you actually track it down?

# %%
# Paste or rebuild your Project 1B code below, then add an inventory list and integrate it.
# TODO: create an inventory list with at least one starting item

# TODO: add at least one .append() somewhere in your adventure

# TODO: print the inventory somewhere the player will see it

# %% [markdown]
# ## The Debugging Round
#
# Once the cell above runs cleanly, **copy your finished code into the cell below**, then deliberately introduce 2–3 bugs into *this copy only* (leave the working version above untouched). Run it, use what you practiced in 1.8 — read the traceback bottom-up, add `print()` statements to trace values, hand-trace the logic — and fix each bug one at a time.

# %%
# Paste your working code here, then break it on purpose and debug it back to working.

# %% [markdown]
# ## Before You Commit
#
# Run your final, de-bugged version top to bottom, start to finish, at least twice with different choices. This is the version that goes in your portfolio as your Unit 1 deliverable — make sure it's the one you're proud of.

# %% [markdown]
# ## AI Collaboration Log
#
# If you used AI for any part of this project, log it here before you commit — same habit as your portfolio README:
#
# - What did you ask for?
# - What did you keep, and what did you change?
#
# *(If you didn't use AI this time, just write "Didn't use AI for this one.")*
#
# **Your log:** *(double-click to edit this cell)*
