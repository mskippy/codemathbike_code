# %% [markdown]
# # Project 1B — The Adventure Loops
#
# **Checkpoint 2 of 3.** Open your Project 1A notebook — this project starts from that code, not from scratch. Right now your character makes exactly one decision and the story ends. Today you turn that one-shot decision into a multi-room adventure using a loop, and wrap your repeated actions (describing a room, handling a choice) into functions.

# %% [markdown]
# ## Requirements
#
# **Tier 1 — Minimum viable:**
# 1. Copy your Project 1A code in as a starting point
# 2. A loop (`while` or `for`) that lets the player move through **at least 3 rooms**, one at a time
# 3. A function `describe_room(...)` that takes at least one parameter and returns or prints a room's description
# 4. A function that handles the player's choice in a room (can be the same function as your branching logic from 1A, now wrapped in a `def`)
# 5. The adventure should be able to end (the loop should stop) — either after a fixed number of rooms, or when a condition is met (health reaches 0, reaching a final room, etc.)
#
# **Tier 2 — Aim for this:**
# - Your room-handling function takes the room's name/description *and* the danger level or contents as separate parameters
# - At least one function `return`s a value that the rest of your program actually uses (not just `print()`s)
# - Each room feels different — a different description, a different choice, not the same text repeated with a new number
#
# **Tier 3 — Stretch:**
# - Use `break` to let the adventure end early under some condition (e.g. health drops too low partway through)
# - Track something across rooms (e.g. total gold collected using a running total variable updated each loop) and report it at the end

# %%
# Paste or rebuild your Project 1A code below as your starting point, then extend it.
# TODO: wrap your room description in a function, e.g. def describe_room(name, danger_level):

# TODO: wrap your choice-handling logic in a function

# TODO: write a loop that calls these functions for at least 3 rooms in a row

# TODO: make sure the loop actually ends somehow

# %% [markdown]
# ## Before You Commit
#
# Run your notebook top to bottom and play through the whole adventure at least twice, making different choices each time. Confirm the loop actually stops when it's supposed to — an adventure that never ends is a bug, not a feature (unless you've deliberately used `break` and tested that path too).

# %% [markdown]
# ## AI Collaboration Log
#
# If you used AI for any part of this project, log it here before you commit — same habit as your portfolio README:
#
# - What did you ask for?
# - What did you keep, and what did you change?
#
# *(If you didn't use AI this time, just write "Didn't use AI for this one.")*
#
# **Your log:** *(double-click to edit this cell)*
