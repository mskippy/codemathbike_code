# %% [markdown]
# # Welcome to Jupyter Notebooks!
#
# This is a **notebook** — a mix of text (like this) and code you can actually run, one small piece at a time.
#
# A few things to know before you start:
# - Notebooks are made of **cells**. This one is a *text* cell. The ones below with code in them are *code* cells.
# - To run a code cell, click into it and press **Shift + Enter**. It runs that cell and jumps to the next one.
# - Cells run in order, top to bottom — if something's not working, try running earlier cells again first.
# - You can edit any code cell and re-run it as many times as you want.
#
# **Before you start:** save this file into your cloned repo folder, then commit it in GitHub Desktop — that's your practice rep for today's local workflow. Come back and finish the notebook after.

# %% [markdown]
# ---
# ## 1. Variables & print()
#
# Run the cell below, then change the value of `name` to your own name and run it again.

# %%
name = "Ms. Smith"
print("Hi, I'm " + name + "!")

# %% [markdown]
# **Your turn:** add a second variable below for your favourite subject, and print a sentence using it.

# %%
# your code here

# %% [markdown]
# ---
# ## 2. input()
#
# `input()` pauses your program and waits for the person running it to type something. Run this cell and try it.

# %%
favourite_language = input("What programming language are you most curious about? ")
print("Nice choice — " + favourite_language + " is a good one to explore.")

# %% [markdown]
# ---
# ## 3. Conditionals (if / else)
#
# Conditionals let your program make decisions. Run this one a few times with different numbers.

# %%
number = 7

if number % 2 == 0:
    print(str(number) + " is even.")
else:
    print(str(number) + " is odd.")

# %% [markdown]
# **Your turn:** write a conditional that checks if `number` is greater than 10, and prints a different message for each case.

# %%
number = 15

# your code here

# %% [markdown]
# ---
# ## 4. Loops
#
# Loops repeat something for every item in a list. Run this one.

# %%
things_i_like = ["pizza", "video games", "long walks on the beach"]

for thing in things_i_like:
    print("I like " + thing)

# %% [markdown]
# **Your turn:** make your own list of 3–5 things (interests, games, songs — your call), and loop over it to print each one.

# %%
# your code here

# %% [markdown]
# ---
# ## 5. Put it together
#
# **Open challenge:** using variables, input(), a conditional, and a loop from above, write a tiny program that:
# 1. Asks the person for their name
# 2. Asks them how many things they want to list
# 3. Loops that many times, asking for one thing each time
# 4. Prints all the things back to them at the end
#
# Already comfortable with all of this? Add something you haven't been taught here yet — impress me.

# %%
# your code here

# %% [markdown]
# ---
# ## AI note
#
# If you used AI (ChatGPT, Copilot, etc.) for any part of this, jot one line below — what did you ask for, and what did you keep or change? No penalty either way, this just starts the habit.

# %% [markdown]
# *Your AI note here.*

# %% [markdown]
# ---
# ### Done?
#
# Commit this file again in GitHub Desktop — that's your second local commit for today. Then let me know you're finished.
